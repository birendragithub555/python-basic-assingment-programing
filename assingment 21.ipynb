# %% [markdown]
# Write a function that takes a list and a number as arguments. Add the number to the end of
# the list, then remove the first element of the list. The function should then return the updated
# list.

# %%
def add_new(a,b):
    l=[]
    if a==[]:
        print("no list selected")
    else:
        for i in range(1,len(a)):
            l.append(a[i])
        l.append(b)
        return l
add_new([1,2,3,4,5],6)
# Out:
# [2, 3, 4, 5, 6]

# %%
add_new([],6)
# Out:
# no list selected

# %% [markdown]
# Create the function that takes a list of dictionaries and returns the sum of people&#39;s budgets.
# Examples
# get_Create the function that takes a list of dictionaries and returns the sum of people&#39;s budgets.
# Examples
# get_budgets([
#   { "name": "John", "age": 21, "budget": 23000 },
#   { "name": "Steve",  "age": 32, "budget": 40000 },
#   { "name": "Martin",  "age": 16, "budget": 2700 }

# %%
def get_budgets(a):
    d=0
    for i in a:
        d=d+i["budget"]
    return d

get_budgets([
  { "name": "John", "age": 21, "budget": 23000 },
  { "name": "Steve",  "age": 32, "budget": 40000 },
  { "name": "Martin",  "age": 16, "budget": 2700 }])
# Out:
# 65700

# %% [markdown]
# Create a function that takes a string and returns a string with its letters in alphabetical order.

# %%
def stralpha(a):
    b=list(a)
    c=sorted(b)
    d="".join(c)
    return d
stralpha("hello")
# Out:
# 'ehllo'

# %%
10000*(1+(0.06)/12)**(10*12)
# Out:
# 18193.9673403229

# %% [markdown]
# Suppose that you invest $10,000 for 10 years at an interest rate of 6% compounded monthly.
# What will be the value of your investment at the end of the 10 year period?
# Create a function that accepts the principal p, the term in years t, the interest rate r, and the
# number of compounding periods per year n. The function returns the value at the end of term
# rounded to the nearest cent.

# %%
def compunded(a,b,c,d):
    anual_income=a*(1+(c/d))**(b*d)
    print(f"{anual_income:.2f}")

compunded(100000, 20, 0.15, 365)
# Out:
# 2007316.26

# %% [markdown]
# Write a function that takes a list of elements and returns only the integers.

# %%
def inttoreturn(a):
    l=[]
    for i in a:
        if str(i).isdigit()==True:
            l.append(i)
        else:continue
    return l

inttoreturn([9, 2, "space", "car", "lion", 16])
# Out:
# [9, 2, 16]
