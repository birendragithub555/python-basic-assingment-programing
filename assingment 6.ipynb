# %%
#Write a Python Program to Display Fibonacci Sequence Using Recursion?
def recursive(n):
    if n<=1:
        return n
    else:
        return(recursive(n-1)+recursive(n-2))
fibo=int(input("enter number of terms"))
for i in range(0,fibo+1):
    print(recursive(i))
# Out:
# enter number of terms 8
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %%
#Write a Python Program to Find Factorial of Number Using Recursion?
def recurfact(n):
    if n<=1:
        return n
    else:
        return n*recurfact(n-1)
fact=int(input("enter number of factorial"))
print("the factorial of number {} is:{}".format(fact,recurfact(fact)))
# Out:
# enter number of factorial 5
# the factorial of number 5 is:120

# %%
#Write a Python Program to calculate your Body Mass Index?
def bmi(weight,height):
    bmi1=float((weight)/(height*height))
    return bmi1
weight=float(input("enter weight in kg"))
height=float(input("enter height in meters"))
print("your BMI is:{}".format(bmi(weight,height)))
# Out:
# enter weight in kg 70
# enter height in meters 1.58
# your BMI is:28.040378144528116

# %%
#Write a Python Program to calculate the natural logarithm of any number?
import math
num=float(input("enter your number for natural log"))
print("natural log of {} is:{}".format(num,math.log(num)))
# Out:
# enter your number for natural log 7
# natural log of 7.0 is:1.9459101490553132

# %%
#Write a Python Program for cube sum of first n natural numbers?
def cube(n):
    if n<=1:
        return n
    else:
        return n*n*n+cube(n-1)
num=float(input("enter number for cube "))
print("the cube of {} natural number is:{}".format(num,cube(num)))
# Out:
# enter number for cube  5
# the cube of 5.0 natural number is:225.0
