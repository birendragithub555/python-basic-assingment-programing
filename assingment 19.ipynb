# %% [markdown]
# Create a function that takes a string and returns a string in which each character is repeated
# once.

# %%
def word_rep(a):
	b=str()
	for i in a:
		b=b+i*2
	return b

word_rep("String")
# Out:
# 'SSttrriinngg'

# %% [markdown]
# Create a function that reverses a boolean value and returns the string &quot;boolean expected&quot;
# if another variable type is given.

# %%
def reverse_boolean(a):
	if type(a)==bool:
		if a==True:
			return False
		elif a==False:
			return True
	else:print("boolean expected")

reverse_boolean(True)
reverse_boolean(0)
# Out:
# boolean expected

# %% [markdown]
# Create a function that returns the thickness (in meters) of a piece of paper after folding it n
# number of times. The paper starts off with a thickness of 0.5mm.

# %%
def thickness_fold(a):
    thick=0.0005
    for i in range(1,a+1):
        thick=thick*2
    print("paper folded {} times has thickness {}".format(a,thick))

thickness_fold(21)
# Out:
# paper folded 21 times has thickness 1048.576

# %% [markdown]
# Create a function that takes a single string as argument and returns an ordered list containing
# the indices of all capital letters in the string.

# %%
def ordered_list(a):
    l=[]
    for i in range(len(a)):
        if a[i].isupper()==True:
            l.append(i)
        b=sorted(l)
    return b

ordered_list("eDaBIt")
# Out:
# [1, 3, 4]

# %% [markdown]
# Using list comprehensions, create a function that finds all even numbers from 1 to the given
# number.

# %%
def even_numbers(n):
    even=[i for i in range(1,n+1) if i%2==0]
    print(even)
    
even_numbers(10)
# Out:
# [2, 4, 6, 8, 10]
