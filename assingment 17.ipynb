# %% [markdown]
# Question1. Create a function that takes three arguments a, b, c and returns the sum of the
# numbers that are evenly divided by c from the range a, b inclusive.

# %%
def evenly_divisble(a,b,c):
    l=[]
    count=1
    for i in range(a,b+1):
        if i%c==0:
            l.append(i)
        else:continue
    if l==[]:
        print("No number between {} and {} can be evenly divided by {}".format(a,b,c))
    else:
        return sum(l)
evenly_divisble(1,10,2)
# Out:
# 30

# %% [markdown]
# Question2. Create a function that returns True if a given inequality expression is correct and
# False otherwise.

# %%
def inequaltiy_exp(a):
    return eval(a)

inequaltiy_exp("2>3>4>5>7")
# Out:
# False

# %% [markdown]
# Question3. Create a function that replaces all the vowels in a string with a specified character.

# %%
def vowels_replace(a,b):
    print(a)
    s=[]
    vowels=["a","e","i","o","u"]
    for i in a:
        if i in vowels:
            f=a.replace(i,b)
            a=f
        else:continue
    return a

vowels_replace("the aardvark&quot","#")
# Out:
# the aardvark&quot
# 'th# ##rdv#rk&q##t'

# %% [markdown]
# Question4. Write a function that calculates the factorial of a number recursively.

# %%
def factorial_recur(a):
    if a==0:
        return 1
    else:
        return a*factorial_recur(a-1)
factorial_recur(8)
# Out:
# 40320

# %% [markdown]
# Create a function that computes the hamming distance between two strings.

# %%
def hamming_distance():
    str1=input("enter your string 1")
    str2=input("enter your string 2")
    if len(str1)!=len(str2):
        print("enter same length characters")
    else:
        d={}
        l=[]
        for k,v in zip(str1,str2):
            d[k]=v
        count=1
        for k,v in d.items():
            if k!=v:
                #print("hammer {}-{} and {} is the diffrence in character".format(count,k,v))
                count=count+1
        print(count-1)

hamming_distance()
# Out:
# enter your string 1 abcde
# enter your string 2 edbca
# 5
