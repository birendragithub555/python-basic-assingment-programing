# %%
#Q1
print("Hello Python")
# Out:
# Hello Python

# %%
#Q2
a=int(input("enter your first number"))
b=int(input("enter your second number"))
print("addition of number is {}".format(a+b))
print("division of number is {}".format(a/b))
# Out:
# enter your first number 5
# enter your second number 2
# addition of number is 7
# division of number is 2.5

# %%
#Q3
a=int(input("enter base of traingle"))
b=int(input("enter height of traingle"))
print("area of traingle  is {}".format(0.5*a*b))
# Out:
# enter base of traingle 6
# enter height of traingle 8
# area of traingle  is 24.0

# %%
#Q4
a=int(input("enter your first number"))
b=int(input("enter your second number"))
if a!=b:
    temp=a
    a=b
    b=temp
    print("after swapping a={} and b={}".format(a,b))
else:print('same number')
# Out:
# enter your first number 4
# enter your second number 4
# same number

# %%
#Q5-Write a Python program to generate a random number?

import random
a=random.randint(1,100)
print(a)
# Out:
# 87
